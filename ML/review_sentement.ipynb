# %%
import pickle 
import pandas as pd
import numpy as np
from tqdm import tqdm
import time

# %%
large = pd.read_csv("large.csv")
large
# Out:
#           Unnamed: 0            steamid   appid  voted_up  votes_up  \
# 0            5000000  76561198147524600  208730     False         5
# 1            5000001  76561198036391642  208730     False        18
# 2            5000002  76561198068984010  208730      True         0
# 3            5000003  76561198130204844  208730      True         4
# 4            5000004  76561198054094015  208730     False         3
# ...              ...                ...     ...       ...       ...
# 10437466    15437466  76561198044371296  535520      True         0
# 10437467    15437467  76561198027331588  535690      True         6
# 10437468    15437468  76561198072234306  535690      True         3
# 10437469    15437469  76561198011544203  535690     False         0
# 10437470    15437470  76561198049199184  535690      True        14
#
#           votes_funny  weighted_vote_score  playtime_forever  \
# 0                   2             0.467759              1306
# ...

# %%
len(large["appid"].unique())
# Out:
# 6599

# %%
temp = []
for i in  tqdm(large["appid"].unique()):
    votes_dict = {}
    votes = large[large['appid']==i]["voted_up"]
    votes_dict["votes_up"] = list(votes)
    votes_dict["appid"] = i
    temp.append(votes_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8850c641d4e3> in <module>
#       1 temp = []
# ----> 2 for i in  tqdm(large["appid"].unique()):
#       3     votes_dict = {}
#       4     votes = large[large['appid']==i]["voted_up"]
#       5     votes_dict["votes_up"] = list(votes)
#
# NameError: name 'tqdm' is not defined

# %%
data = pd.DataFrame(temp)

# %%
positive = []
negative = []
for i in range(len(data)):
    total_votes = len(data["votes_up"][i])
    no_of_positive = sum(data["votes_up"][i])
    no_of_negative = total_votes-no_of_positive
    positive.append((no_of_positive/total_votes)*100)
    negative.append((no_of_negative/total_votes)*100)

# %%
data["positive"] = positive
data["negative"] = negative

# %%
data

# %%
data.to_pickle("./review_sentement")
